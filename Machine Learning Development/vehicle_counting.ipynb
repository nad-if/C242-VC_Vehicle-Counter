# %%
import cv2
from ultralytics import YOLO
from collections import defaultdict
import time

# Load the YOLO model
model = YOLO('yolo11n.pt')

# %%
# class_list
class_list = model.names
print(class_list)
# Out:
# {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}

# %%
# Open the video file
cap = cv2.VideoCapture('test.mp4')

# Get the width and height of the frames
frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

# Define the codec and create VideoWriter object
out = cv2.VideoWriter('output.mp4', cv2.VideoWriter_fourcc(*'mp4v'), 10, (frame_width, frame_height))

# Dictionary to store object counts by class
class_counts = defaultdict(int)

# Dictionary to keep track of object IDs that have crossed the line
crossed_ids = set()

# Red Line Coordinates
red_line = 360

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    # Resize frame
    resized_frame = cv2.resize(frame, (640, 480))

    # Run YOLO tracking on the frame
    results = model.track(resized_frame, persist=True, classes=[2, 3, 5, 7])

    # Ensure results are not empty
    if results[0].boxes.data is not None:
        # Get the detected boxes, their class indices, and track IDs
        boxes = results[0].boxes.xyxy.cpu()
        track_ids = results[0].boxes.id.cpu().tolist() if results[0].boxes.id is not None else []
        class_indices = results[0].boxes.cls.cpu().tolist() if results[0].boxes.cls is not None else []
        confidences = results[0].boxes.conf.cpu() if results[0].boxes.conf is not None else []

        cv2.line(resized_frame, (0, red_line), (640, red_line), (0, 0, 255), 3)

        # Loop through each detected object
        for box, track_id, class_idx, conf in zip(boxes, track_ids, class_indices, confidences):
            x1, y1, x2, y2 = map(int, box)
            cx = (x1 + x2) // 2  # Calculate the center point
            cy = (y1 + y2) // 2

            class_name = class_list[class_idx]

            cv2.circle(resized_frame, (cx, cy), 4, (0, 0, 255), -1)

            cv2.putText(resized_frame, f"ID: {track_id} {class_name}", (x1, y1 - 10),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 255, 255), 2)
            cv2.rectangle(resized_frame, (x1, y1), (x2, y2), (0, 255, 0), 2)

            # Check if the object has crossed the red line
            if cy > red_line and track_id not in crossed_ids:
                # Mark the object as crossed
                crossed_ids.add(track_id)
                class_counts[class_name] += 1

        # Display the counts on the frame
        y_offset = 30
        for class_name, count in class_counts.items():
            cv2.putText(resized_frame, f"{class_name}: {count}", (10, y_offset),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 255, 0), 2)
            y_offset += 30

    # Write the frame to the output video
    out.write(resized_frame)

    # Show the frame
    cv2.imshow("Object Tracking & Counting", resized_frame)

    # Exit loop if 'q' key is pressed
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release resources
cap.release()
out.release()
cv2.destroyAllWindows()
# Out:
# 0: 480x640 6 cars, 1 bus, 1 truck, 225.0ms
# Speed: 3.3ms preprocess, 225.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 1 truck, 196.7ms
# Speed: 3.6ms preprocess, 196.7ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 1 bus, 191.1ms
# Speed: 0.0ms preprocess, 191.1ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 1 bus, 183.4ms
# Speed: 1.1ms preprocess, 183.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 1 bus, 158.9ms
# Speed: 2.5ms preprocess, 158.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 1 bus, 135.3ms
# Speed: 5.0ms preprocess, 135.3ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 1 bus, 129.4ms
# Speed: 2.5ms preprocess, 129.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 1 truck, 125.0ms
# Speed: 4.0ms preprocess, 125.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 1 truck, 133.6ms
# Speed: 4.4ms preprocess, 133.6ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 1 truck, 124.7ms
# Speed: 3.0ms preprocess, 124.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 1 truck, 148.5ms
# Speed: 2.6ms preprocess, 148.5ms inference, 5.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 1 truck, 149.6ms
# Speed: 7.6ms preprocess, 149.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 1 bus, 1 truck, 166.2ms
# Speed: 3.8ms preprocess, 166.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 1 truck, 174.8ms
# Speed: 2.5ms preprocess, 174.8ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 1 truck, 148.0ms
# Speed: 3.0ms preprocess, 148.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 1 bus, 1 truck, 158.6ms
# Speed: 3.5ms preprocess, 158.6ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 1 bus, 1 truck, 182.7ms
# Speed: 2.5ms preprocess, 182.7ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 1 bus, 1 truck, 172.3ms
# Speed: 6.0ms preprocess, 172.3ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 1 bus, 1 truck, 160.0ms
# Speed: 2.0ms preprocess, 160.0ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 1 bus, 1 truck, 147.7ms
# Speed: 4.0ms preprocess, 147.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 1 truck, 182.3ms
# Speed: 2.0ms preprocess, 182.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 1 truck, 192.5ms
# Speed: 2.0ms preprocess, 192.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 1 truck, 175.9ms
# Speed: 4.7ms preprocess, 175.9ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 1 truck, 171.7ms
# Speed: 2.0ms preprocess, 171.7ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 2 trucks, 181.7ms
# Speed: 2.5ms preprocess, 181.7ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 1 truck, 180.4ms
# Speed: 3.0ms preprocess, 180.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 1 truck, 179.7ms
# Speed: 4.0ms preprocess, 179.7ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 1 truck, 182.5ms
# Speed: 4.0ms preprocess, 182.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 1 truck, 196.0ms
# Speed: 4.0ms preprocess, 196.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 1 truck, 186.2ms
# Speed: 3.0ms preprocess, 186.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 1 bus, 197.5ms
# Speed: 4.0ms preprocess, 197.5ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 1 truck, 187.3ms
# Speed: 4.0ms preprocess, 187.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 1 truck, 180.3ms
# Speed: 3.0ms preprocess, 180.3ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 1 truck, 191.5ms
# Speed: 4.5ms preprocess, 191.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 1 truck, 173.4ms
# Speed: 4.0ms preprocess, 173.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 2 trucks, 181.5ms
# Speed: 2.5ms preprocess, 181.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 cars, 1 bus, 171.5ms
# Speed: 5.3ms preprocess, 171.5ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 cars, 1 bus, 1 truck, 140.0ms
# Speed: 3.0ms preprocess, 140.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 cars, 1 truck, 148.6ms
# Speed: 2.0ms preprocess, 148.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 2 trucks, 133.1ms
# Speed: 4.0ms preprocess, 133.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 cars, 1 truck, 133.5ms
# Speed: 3.0ms preprocess, 133.5ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 2 trucks, 148.6ms
# Speed: 2.0ms preprocess, 148.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 cars, 2 trucks, 144.1ms
# Speed: 2.0ms preprocess, 144.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 cars, 2 trucks, 140.1ms
# Speed: 2.5ms preprocess, 140.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 cars, 2 trucks, 131.0ms
# Speed: 2.5ms preprocess, 131.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 cars, 2 trucks, 123.9ms
# Speed: 3.1ms preprocess, 123.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 cars, 2 trucks, 148.1ms
# Speed: 3.0ms preprocess, 148.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 1 truck, 145.8ms
# Speed: 2.0ms preprocess, 145.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 1 bus, 2 trucks, 137.0ms
# Speed: 2.5ms preprocess, 137.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 2 trucks, 157.3ms
# Speed: 3.0ms preprocess, 157.3ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 2 trucks, 148.7ms
# Speed: 3.0ms preprocess, 148.7ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 2 trucks, 147.2ms
# Speed: 3.0ms preprocess, 147.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 2 trucks, 139.6ms
# Speed: 3.0ms preprocess, 139.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 2 trucks, 122.5ms
# Speed: 1.6ms preprocess, 122.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 2 trucks, 159.7ms
# Speed: 3.5ms preprocess, 159.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 cars, 2 trucks, 157.8ms
# Speed: 3.0ms preprocess, 157.8ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 2 trucks, 137.6ms
# Speed: 3.0ms preprocess, 137.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 2 trucks, 139.7ms
# Speed: 3.0ms preprocess, 139.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 2 trucks, 121.9ms
# Speed: 2.7ms preprocess, 121.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 1 truck, 107.9ms
# Speed: 3.5ms preprocess, 107.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 1 truck, 117.6ms
# Speed: 3.0ms preprocess, 117.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 1 truck, 117.5ms
# Speed: 2.6ms preprocess, 117.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 2 trucks, 108.9ms
# Speed: 3.0ms preprocess, 108.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 2 trucks, 120.5ms
# Speed: 3.5ms preprocess, 120.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 2 trucks, 115.0ms
# Speed: 2.5ms preprocess, 115.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 1 truck, 122.4ms
# Speed: 2.0ms preprocess, 122.4ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 1 truck, 111.7ms
# Speed: 2.0ms preprocess, 111.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 1 truck, 111.6ms
# Speed: 3.0ms preprocess, 111.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 1 truck, 115.5ms
# Speed: 2.0ms preprocess, 115.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 1 truck, 116.5ms
# Speed: 3.5ms preprocess, 116.5ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 1 truck, 153.5ms
# Speed: 3.0ms preprocess, 153.5ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 1 truck, 116.4ms
# Speed: 3.0ms preprocess, 116.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 1 truck, 123.5ms
# Speed: 2.5ms preprocess, 123.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 1 truck, 112.2ms
# Speed: 2.5ms preprocess, 112.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 1 truck, 123.9ms
# Speed: 2.5ms preprocess, 123.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 1 truck, 155.6ms
# Speed: 3.5ms preprocess, 155.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 2 trucks, 161.1ms
# Speed: 2.5ms preprocess, 161.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 1 truck, 151.2ms
# Speed: 4.0ms preprocess, 151.2ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 1 truck, 145.6ms
# Speed: 3.0ms preprocess, 145.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 1 truck, 165.2ms
# Speed: 3.0ms preprocess, 165.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 1 truck, 145.1ms
# Speed: 2.0ms preprocess, 145.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 1 truck, 132.2ms
# Speed: 2.5ms preprocess, 132.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 130.5ms
# Speed: 4.0ms preprocess, 130.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 131.6ms
# Speed: 2.0ms preprocess, 131.6ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 137.1ms
# Speed: 3.5ms preprocess, 137.1ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 134.6ms
# Speed: 2.0ms preprocess, 134.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 137.0ms
# Speed: 2.5ms preprocess, 137.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 128.1ms
# Speed: 3.5ms preprocess, 128.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 135.5ms
# Speed: 3.0ms preprocess, 135.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 131.1ms
# Speed: 3.0ms preprocess, 131.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 131.0ms
# Speed: 3.0ms preprocess, 131.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 127.0ms
# Speed: 2.5ms preprocess, 127.0ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 144.2ms
# Speed: 3.0ms preprocess, 144.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 142.6ms
# Speed: 3.0ms preprocess, 142.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 124.0ms
# Speed: 2.5ms preprocess, 124.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 152.7ms
# Speed: 2.5ms preprocess, 152.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 145.6ms
# Speed: 4.5ms preprocess, 145.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 137.0ms
# Speed: 2.5ms preprocess, 137.0ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 1 truck, 119.0ms
# Speed: 2.0ms preprocess, 119.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 114.2ms
# Speed: 2.0ms preprocess, 114.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 119.9ms
# Speed: 3.0ms preprocess, 119.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 115.4ms
# Speed: 1.5ms preprocess, 115.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 127.0ms
# Speed: 2.0ms preprocess, 127.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 112.3ms
# Speed: 2.6ms preprocess, 112.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 118.4ms
# Speed: 3.0ms preprocess, 118.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 112.4ms
# Speed: 3.5ms preprocess, 112.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 116.4ms
# Speed: 2.0ms preprocess, 116.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 114.9ms
# Speed: 2.5ms preprocess, 114.9ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 121.0ms
# Speed: 4.0ms preprocess, 121.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 117.5ms
# Speed: 2.0ms preprocess, 117.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 109.4ms
# Speed: 2.5ms preprocess, 109.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 116.4ms
# Speed: 2.5ms preprocess, 116.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 119.1ms
# Speed: 3.0ms preprocess, 119.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 116.0ms
# Speed: 3.0ms preprocess, 116.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 115.5ms
# Speed: 3.5ms preprocess, 115.5ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 112.4ms
# Speed: 4.0ms preprocess, 112.4ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 126.4ms
# Speed: 2.0ms preprocess, 126.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 118.0ms
# Speed: 3.0ms preprocess, 118.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 115.2ms
# Speed: 3.0ms preprocess, 115.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 111.5ms
# Speed: 3.0ms preprocess, 111.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 145.2ms
# Speed: 3.0ms preprocess, 145.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 149.3ms
# Speed: 3.0ms preprocess, 149.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 142.4ms
# Speed: 1.5ms preprocess, 142.4ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 152.1ms
# Speed: 5.0ms preprocess, 152.1ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 158.8ms
# Speed: 3.0ms preprocess, 158.8ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 170.0ms
# Speed: 2.5ms preprocess, 170.0ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 153.6ms
# Speed: 4.0ms preprocess, 153.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 129.1ms
# Speed: 3.0ms preprocess, 129.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 114.0ms
# Speed: 2.5ms preprocess, 114.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 122.0ms
# Speed: 2.0ms preprocess, 122.0ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 126.7ms
# Speed: 3.0ms preprocess, 126.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 111.9ms
# Speed: 3.0ms preprocess, 111.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 126.5ms
# Speed: 2.0ms preprocess, 126.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 113.5ms
# Speed: 2.0ms preprocess, 113.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 113.4ms
# Speed: 2.5ms preprocess, 113.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 106.9ms
# Speed: 3.0ms preprocess, 106.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 114.5ms
# Speed: 2.5ms preprocess, 114.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 117.0ms
# Speed: 3.0ms preprocess, 117.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 111.9ms
# Speed: 3.0ms preprocess, 111.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 113.0ms
# Speed: 2.0ms preprocess, 113.0ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 143.6ms
# Speed: 3.5ms preprocess, 143.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 136.1ms
# Speed: 4.0ms preprocess, 136.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 118.0ms
# Speed: 4.0ms preprocess, 118.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 143.1ms
# Speed: 2.0ms preprocess, 143.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 136.9ms
# Speed: 4.6ms preprocess, 136.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 124.1ms
# Speed: 2.0ms preprocess, 124.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 cars, 114.1ms
# Speed: 3.0ms preprocess, 114.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 cars, 116.9ms
# Speed: 3.5ms preprocess, 116.9ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 1 truck, 144.1ms
# Speed: 2.5ms preprocess, 144.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 1 truck, 124.4ms
# Speed: 4.5ms preprocess, 124.4ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 cars, 106.7ms
# Speed: 3.0ms preprocess, 106.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 cars, 114.2ms
# Speed: 2.0ms preprocess, 114.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 cars, 119.0ms
# Speed: 2.0ms preprocess, 119.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 cars, 115.5ms
# Speed: 2.0ms preprocess, 115.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 cars, 122.1ms
# Speed: 3.6ms preprocess, 122.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 cars, 121.5ms
# Speed: 3.5ms preprocess, 121.5ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 1 truck, 114.9ms
# Speed: 2.5ms preprocess, 114.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 1 truck, 109.0ms
# Speed: 2.0ms preprocess, 109.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 1 truck, 109.9ms
# Speed: 3.0ms preprocess, 109.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 1 truck, 117.9ms
# Speed: 3.5ms preprocess, 117.9ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 1 truck, 115.0ms
# Speed: 3.0ms preprocess, 115.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 1 truck, 157.6ms
# Speed: 3.5ms preprocess, 157.6ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 1 truck, 114.4ms
# Speed: 2.0ms preprocess, 114.4ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 1 truck, 111.5ms
# Speed: 2.5ms preprocess, 111.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 1 truck, 132.5ms
# Speed: 2.0ms preprocess, 132.5ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 1 truck, 115.5ms
# Speed: 2.5ms preprocess, 115.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 1 truck, 114.0ms
# Speed: 4.6ms preprocess, 114.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 1 truck, 113.9ms
# Speed: 4.6ms preprocess, 113.9ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 1 truck, 117.9ms
# Speed: 2.0ms preprocess, 117.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 1 truck, 123.4ms
# Speed: 2.0ms preprocess, 123.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 1 truck, 108.9ms
# Speed: 2.5ms preprocess, 108.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 1 truck, 121.1ms
# Speed: 2.5ms preprocess, 121.1ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 1 truck, 113.5ms
# Speed: 2.0ms preprocess, 113.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 1 truck, 133.6ms
# Speed: 3.7ms preprocess, 133.6ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 1 truck, 147.9ms
# Speed: 3.0ms preprocess, 147.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 1 truck, 120.1ms
# Speed: 3.0ms preprocess, 120.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 1 truck, 117.7ms
# Speed: 4.0ms preprocess, 117.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 1 truck, 169.6ms
# Speed: 3.6ms preprocess, 169.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 1 truck, 169.8ms
# Speed: 4.0ms preprocess, 169.8ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 1 truck, 151.7ms
# Speed: 3.0ms preprocess, 151.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 1 truck, 142.1ms
# Speed: 3.0ms preprocess, 142.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 1 truck, 140.4ms
# Speed: 2.0ms preprocess, 140.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 1 truck, 131.5ms
# Speed: 2.0ms preprocess, 131.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
